# %% [markdown]
# <a href="https://colab.research.google.com/github/Carmen-88/DSC-502/blob/main/Homework_1_CSchuler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/DATA/olympic_medals.csv')

df.head()
# Out:
#   Gender       Event Location  Year Medal                   Name Nationality  \
# 0      M  10000M Men      Rio  2016     G          Mohamed FARAH         GBR
# 1      M  10000M Men      Rio  2016     S  Paul Kipngetich TANUI         KEN
# 2      M  10000M Men      Rio  2016     B           Tamirat TOLA         ETH
# 3      M  10000M Men  Beijing  2008     G        Kenenisa BEKELE         ETH
# 4      M  10000M Men  Beijing  2008     S         Sileshi SIHINE         ETH
#
#      Result
# 0  25:05.17
# 1  27:05.64
# 2  27:06.26
# 3  27:01.17
# 4  27:02.77

# %%
# a. Find the size of the data frame. How many rows, how many columns?

df.shape

#There are 2394 rows and 8 columns.
# Out:
# (2394, 8)

# %%
# b. Use the appropriate function to report the data types for all columns.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2394 entries, 0 to 2393
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       2394 non-null   object
#  1   Event        2394 non-null   object
#  2   Location     2394 non-null   object
#  3   Year         2394 non-null   int64
#  4   Medal        2394 non-null   object
#  5   Name         2164 non-null   object
#  6   Nationality  2394 non-null   object
#  7   Result       2351 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 149.8+ KB

# %%
# c. Find how many unique cities matches were held at. (Hint: unique(). For instance, the following example tells how many unique Events held: len(medals['Event'].unique()))

len(df['Location'].unique())

#There are 23 unique cities matches were held at.
# Out:
# 23

# %%
# d. Find how many medals the USA team won in total.

df[df['Nationality'] == 'USA']['Medal'].count()

#The USA team won 638 medals.
# Out:
# np.int64(638)

# %%
# e. Find the total number of medals for each Nationality. (Hint: please search for groupby() function with count. For instance, the following example counts at how many locations each event was held.
          #medals.groupby(by='Event')['Location'].count())


df.groupby(by='Nationality')['Medal'].count()
# Out:
# Nationality
# ALG      9
# ARG      4
# AUS     57
# AUT      4
# BAH     12
#       ...
# URS    131
# USA    638
# VEN      2
# YUG      1
# ZAM      1
# Name: Medal, Length: 97, dtype: int64
